# %% [markdown]
# <a href="https://colab.research.google.com/github/NataliaLak/Tasks/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('sample_data/california_housing_test.csv')
# df.head()
# df.tail()
df.shape
# df.isnull().sum()

# df.columns
# df[df['housing_median_age'] > 52]
# Out:
# (3000, 9)

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
df[df['median_income']<2] [['median_house_value', 'population']]
# Out:
#       median_house_value  population
# 5                67000.0       663.0
# 6                67000.0       604.0
# 16              181300.0       189.0
# 28              350000.0      3751.0
# 43               79300.0       737.0
# ...                  ...         ...
# 2943             57200.0      1591.0
# 2964             91300.0      1305.0
# 2985            109400.0       642.0
# 2986             85400.0       899.0
# 2995            225000.0      1258.0
#
# [360 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# ...

# %%
df[(df['housing_median_age'] < 20) & (df['median_house_value'] > 70000)]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4       -119.67     36.33                19.0       1241.0           244.0
# 7       -120.65     35.48                19.0       2310.0           471.0
# 8       -122.84     38.40                15.0       3080.0           617.0
# 13      -117.03     32.97                16.0       3936.0           694.0
# 16      -120.81     37.53                15.0        570.0           123.0
# ...         ...       ...                 ...          ...             ...
# 2978    -121.34     38.64                17.0       2761.0           501.0
# 2981    -120.66     35.49                17.0       4422.0           945.0
# 2984    -117.59     33.88                13.0       3239.0           849.0
# 2985    -120.47     34.94                17.0       1368.0           308.0
# 2991    -117.17     34.28                13.0       4867.0           718.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df['median_house_value'].min()
# Out:
# 22500.0

# %%
df[df['median_income'] == 3.1250] ['median_house_value'].max()
# Out:
# 233300.0

# %%
min_val = df['median_house_value'].min()
df['population'][df['median_house_value'] == min_val]
# Out:
# 2001    1230.0
# Name: population, dtype: float64

# %%
min_val = df['median_house_value'].min()
df[df['median_house_value'] == min_val]['population'].max()
# Out:
# 1230.0

# %%
df.loc[df['housing_median_age'] < 20, ['total_bedrooms','total_rooms']]
# Out:
#       total_bedrooms  total_rooms
# 4              244.0       1241.0
# 7              471.0       2310.0
# 8              617.0       3080.0
# 13             694.0       3936.0
# 16             123.0        570.0
# ...              ...          ...
# 2981           945.0       4422.0
# 2984           849.0       3239.0
# 2985           308.0       1368.0
# 2991           718.0       4867.0
# 2997           201.0        956.0
#
# [830 rows x 2 columns]

# %%
for col in df.columns[:2]:
  print(df[col], end=' ')
# Out:
# 0      -122.05
# 1      -118.30
# 2      -117.81
# 3      -118.36
# 4      -119.67
#          ...
# 2995   -119.86
# 2996   -118.14
# 2997   -119.70
# 2998   -117.12
# 2999   -119.63
# Name: longitude, Length: 3000, dtype: float64 0       37.37
# 1       34.26
# 2       33.78
# 3       33.82
# 4       36.33
#         ...
# 2995    34.42
# 2996    34.06
# 2997    36.30
# 2998    34.10
# 2999    34.42
# Name: latitude, Length: 3000, dtype: float64
